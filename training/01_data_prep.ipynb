# %% [markdown]
# # Data Preparation
#
# This notebook handles downloading the dataset (e.g., MNIST, HASYv2) and performing data augmentation.

# %%
import os
import numpy as np
import matplotlib.pyplot as plt

# %%
# Define paths
RAW_DATA_DIR = 'raw_data/'
os.makedirs(RAW_DATA_DIR, exist_ok=True)
